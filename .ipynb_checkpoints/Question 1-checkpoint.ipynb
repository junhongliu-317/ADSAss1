# %%
import pandas as pd
import seaborn as sns

data = pd.read_csv('./TC.csv')


data = data.drop('Unnamed: 0', axis = 1)
cor = data.corr()
print(cor)
ax = sns.heatmap(
    cor, 
    square=True
)
# Out:
#               V1        V2            V3        V4            V5        V6
# V1  1.000000e+00  0.043685  1.690309e-01  0.086066  7.804078e-17  0.086066
# V2  4.368520e-02  1.000000  7.384147e-02  0.203030  8.737041e-02 -0.067677
# V3  1.690309e-01  0.073841  1.000000e+00  0.043644 -1.161321e-17  0.130931
# V4  8.606630e-02  0.203030  4.364358e-02  1.000000  7.745967e-01  0.600000
# V5  7.804078e-17  0.087370 -1.161321e-17  0.774597  1.000000e+00  0.774597
# V6  8.606630e-02 -0.067677  1.309307e-01  0.600000  7.745967e-01  1.000000

# %%
data = pd.read_csv("./SM1.csv")
data = data.drop('Unnamed: 0', axis = 1)
ax = sns.heatmap(data, square = True)

# %%
data = pd.read_csv("./SM2.csv")
data = data.drop('Unnamed: 0', axis = 1)
ax = sns.heatmap(data, square = True)

# %%
data = pd.read_csv("./SM3.csv")
data = data.drop('Unnamed: 0', axis = 1)
ax = sns.heatmap(data, square = True)

# %%
data = pd.read_csv("./SM4.csv")
data = data.drop('Unnamed: 0', axis = 1)
ax = sns.heatmap(data, square = True)

# %%
data = pd.read_csv("./SM5.csv")
data = data.drop('Unnamed: 0', axis = 1)
ax = sns.heatmap(data, square = True)

# %%
data = pd.read_csv("./SM6.csv")
data = data.drop('Unnamed: 0', axis = 1)
ax = sns.heatmap(data, square = True)

# %%
data = pd.read_csv('./SM.csv')


data = data.drop('Unnamed: 0', axis = 1)
cor = data.corr()
print(cor)
ax = sns.heatmap(
    cor, 
    square=True
)
# Out:
#           V1        V2        V3        V4        V5        V6
# V1  1.000000 -0.060096 -0.066231 -0.066231 -0.060096 -0.060096
# V2 -0.060096  1.000000 -0.066231 -0.066231 -0.060096 -0.060096
# V3 -0.066231 -0.066231  1.000000 -0.072993 -0.066231 -0.066231
# V4 -0.066231 -0.066231 -0.072993  1.000000 -0.066231 -0.066231
# V5 -0.060096 -0.060096 -0.066231 -0.066231  1.000000 -0.060096
# V6 -0.060096 -0.060096 -0.066231 -0.066231 -0.060096  1.000000
