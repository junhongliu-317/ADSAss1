# %%
import pandas as pd
import seaborn as sns

data = pd.read_csv('./TC.csv')

#Generate CM and CM Heatmap of the TC
data = data.drop('Unnamed: 0', axis = 1)
cor = round(data.corr(), 6)
print(cor)
ax = sns.heatmap(
    cor, 
    square=True
)
ax.set_title("TC")
# Out:
#           V1        V2        V3        V4        V5        V6
# V1  1.000000 -0.000000  0.169031  0.086066  0.000000  0.086066
# V2 -0.000000  1.000000 -0.028571  0.130931 -0.000000 -0.130931
# V3  0.169031 -0.028571  1.000000  0.043644 -0.000000  0.130931
# V4  0.086066  0.130931  0.043644  1.000000  0.774597  0.600000
# V5  0.000000 -0.000000 -0.000000  0.774597  1.000000  0.774597
# V6  0.086066 -0.130931  0.130931  0.600000  0.774597  1.000000
# Text(0.5, 1.0, 'TC')

# %%
#Generate heatmap of each SM
data = pd.read_csv("./SM1.csv")
data = data.drop('Unnamed: 0', axis = 1)
xlabels = range(0,21)
ax = sns.heatmap(data,  xticklabels=xlabels, square = True)

# %%
data = pd.read_csv("./SM2.csv")
data = data.drop('Unnamed: 0', axis = 1)
ax = sns.heatmap(data, xticklabels=xlabels, square = True)

# %%
data = pd.read_csv("./SM3.csv")
data = data.drop('Unnamed: 0', axis = 1)
ax = sns.heatmap(data, xticklabels=xlabels,square = True)

# %%
data = pd.read_csv("./SM4.csv")
data = data.drop('Unnamed: 0', axis = 1)
ax = sns.heatmap(data, xticklabels=xlabels,square = True)

# %%
data = pd.read_csv("./SM5.csv")
data = data.drop('Unnamed: 0', axis = 1)
ax = sns.heatmap(data, xticklabels=xlabels,square = True)

# %%
data = pd.read_csv("./SM6.csv")
data = data.drop('Unnamed: 0', axis = 1)
ax = sns.heatmap(data, xticklabels=xlabels,square = True)

# %%
data = pd.read_csv('./SM.csv')

#Generate CM and CM Heatmap of SM matrix
data = data.drop('Unnamed: 0', axis = 1)
cor = round(data.corr(), 6)
print(cor)

ax = sns.heatmap(
    cor, 
    square=True
)
ax.set_title("SM")
# Out:
#           V1        V2        V3        V4        V5        V6
# V1  1.000000 -0.060096 -0.066231 -0.066231 -0.060096 -0.060096
# V2 -0.060096  1.000000 -0.066231 -0.066231 -0.060096 -0.060096
# V3 -0.066231 -0.066231  1.000000 -0.072993 -0.066231 -0.066231
# V4 -0.066231 -0.066231 -0.072993  1.000000 -0.066231 -0.066231
# V5 -0.060096 -0.060096 -0.066231 -0.066231  1.000000 -0.060096
# V6 -0.060096 -0.060096 -0.066231 -0.066231 -0.060096  1.000000
# Text(0.5, 1.0, 'SM')

# %%
data = pd.read_csv('./TCnoise.csv')

#Generate CM and CM heatmap of each noise matrix
data = data.drop('Unnamed: 0', axis = 1)
cor = round(data.corr(), 6)
print(cor)

ax = sns.heatmap(
    cor, 
    square=True,
)
ax.set_title("TCnoise")
# Out:
#           V1        V2        V3        V4        V5        V6
# V1  1.000000 -0.103060 -0.049015 -0.022530 -0.060250  0.081467
# V2 -0.103060  1.000000 -0.052994 -0.020526 -0.077672 -0.161944
# V3 -0.049015 -0.052994  1.000000  0.007281  0.016242  0.057033
# V4 -0.022530 -0.020526  0.007281  1.000000  0.085220 -0.010091
# V5 -0.060250 -0.077672  0.016242  0.085220  1.000000 -0.036015
# V6  0.081467 -0.161944  0.057033 -0.010091 -0.036015  1.000000
# Text(0.5, 1.0, 'TCnoise')

# %%
data = pd.read_csv('./SMnoise.csv')


data = data.drop('Unnamed: 0', axis = 1)
cor = round(data.corr(), 6)
print(cor)

ax = sns.heatmap(
    cor, 
    square=True
)
ax.set_title("SMnoise")
# Out:
#           V1        V2        V3        V4        V5        V6
# V1  1.000000  0.026526  0.088379 -0.017279 -0.073226  0.009400
# V2  0.026526  1.000000 -0.024188 -0.053853 -0.016230  0.061339
# V3  0.088379 -0.024188  1.000000  0.047633 -0.079013 -0.073281
# V4 -0.017279 -0.053853  0.047633  1.000000  0.015801 -0.002693
# V5 -0.073226 -0.016230 -0.079013  0.015801  1.000000  0.055325
# V6  0.009400  0.061339 -0.073281 -0.002693  0.055325  1.000000
# Text(0.5, 1.0, 'SMnoise')
